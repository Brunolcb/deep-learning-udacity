# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.10.0
# Default GPU Device: /device:GPU:0

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function
    real_input = tf.placeholder(tf.float32, [None, image_width, image_height, image_channels])
    z_input = tf.placeholder(tf.float32, [None, z_dim])
    learning_rate = tf.placeholder(tf.float32)
    
    return real_input, z_input, learning_rate


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the discriminator, tensor logits of the discriminator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param images: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function
    alpha = 0.2
    with tf.variable_scope("discriminator", reuse = reuse):
        
        x1 = tf.layers.conv2d(images, 64, 3, strides = 2, padding = 'same')
        x1 = tf.maximum(alpha*x1, x1)
        
        x2 = tf.layers.conv2d(x1, 128, 3, strides = 2, padding = 'same')
        x2 = tf.layers.batch_normalization(x2, training = True)
        x2 = tf.maximum(alpha*x2, x2)
    
        flat = tf.reshape(x2, (-1, 7*7*128)) 
        
        logits = tf.layers.dense(flat, 1)
        out = tf.sigmoid(logits)

        return out, logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    # TODO: Implement Function
    alpha = 0.2
    with tf.variable_scope('generator', reuse = not (is_train)):
        
        x1 = tf.layers.dense(z, 7*7*64)

        x1 = tf.reshape(x1, (-1, 7, 7, 64))
        x1 = tf.layers.batch_normalization(x1, training = is_train)
        x1 = tf.maximum(alpha*x1, x1)
        
        x2 = tf.layers.conv2d_transpose(x1, 128, 3, strides = 2, padding = 'same')
        x2 = tf.layers.batch_normalization(x2, training = is_train)
        x2 = tf.maximum(alpha*x2, x2)

        # Output layer, 32x32x3
        logits = tf.layers.conv2d_transpose(x2, out_channel_dim, 3, strides = 2, padding = 'same')

        out = tf.tanh(logits)
        
        return out



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    g_model = generator(input_z, out_channel_dim)
    d_model_real, d_logits_real = discriminator(input_real)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse = True)

    d_loss_real = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=tf.ones_like(d_model_real)))
    d_loss_fake = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.zeros_like(d_model_fake)))
    g_loss = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.ones_like(d_model_fake)))

    d_loss = d_loss_real + d_loss_fake

    return d_loss, g_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    t_vars = tf.trainable_variables()
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]
    g_vars = [var for var in t_vars if var.name.startswith('generator')]
    
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
        d_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=d_vars)
        g_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(g_loss, var_list=g_vars)

    return d_train_opt, g_train_opt


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    
    real_input, z_input, learn_r = model_inputs(data_shape[1], data_shape[2], data_shape[3], z_dim)
    d_loss, g_loss = model_loss(real_input,z_input,data_shape[3])
    d_opt, g_opt = model_opt(d_loss,g_loss,learning_rate,beta1)
    samples, losses = [], []
    steps =0
    show_every = 100
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                #reescale from -0.5 to 0.5 to -1 to 1
                batch_images = batch_images*2
                # TODO: Train Model
                steps += 1
                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_dim))
                _ = sess.run(d_opt, feed_dict={real_input:batch_images, z_input:batch_z, learn_r:learning_rate})
                _ = sess.run(g_opt,feed_dict={real_input : batch_images, z_input:batch_z})  
                
                if steps % show_every == 0:
                    train_loss_d = d_loss.eval({real_input: batch_images, z_input: batch_z})
                    train_loss_g = g_loss.eval({z_input: batch_z})
                    print("Epoch {}/{}...".format(epoch_i+1, epoch_count),
                        "Discriminator Loss: {:.4f}...".format(train_loss_d),
                        "Generator Loss: {:.4f}".format(train_loss_g))
                    losses.append((train_loss_d, train_loss_g))
                    _= show_generator_output(sess, 4, z_input, data_shape[3], data_image_mode)

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 16
z_dim = 50
learning_rate = 0.0002
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Discriminator Loss: 0.3873... Generator Loss: 2.0986
# Epoch 1/2... Discriminator Loss: 0.7601... Generator Loss: 0.8396
# Epoch 1/2... Discriminator Loss: 0.9833... Generator Loss: 1.3685
# Epoch 1/2... Discriminator Loss: 0.9468... Generator Loss: 1.2965
# Epoch 1/2... Discriminator Loss: 0.8097... Generator Loss: 1.2319
# Epoch 1/2... Discriminator Loss: 1.0375... Generator Loss: 0.9656
# Epoch 1/2... Discriminator Loss: 0.7733... Generator Loss: 1.1556
# Epoch 1/2... Discriminator Loss: 0.7042... Generator Loss: 1.1596
# Epoch 1/2... Discriminator Loss: 0.7690... Generator Loss: 1.0727
# Epoch 1/2... Discriminator Loss: 0.4950... Generator Loss: 1.5767
# Epoch 1/2... Discriminator Loss: 0.5567... Generator Loss: 1.1899
# Epoch 1/2... Discriminator Loss: 0.5485... Generator Loss: 1.4682
# Epoch 1/2... Discriminator Loss: 0.7499... Generator Loss: 0.7936
# Epoch 1/2... Discriminator Loss: 0.4938... Generator Loss: 1.4221
# Epoch 1/2... Discriminator Loss: 0.4477... Generator Loss: 1.4657
# Epoch 1/2... Discriminator Loss: 0.6789... Generator Loss: 1.6012
# Epoch 1/2... Discriminator Loss: 0.5759... Generator Loss: 1.2509
# Epoch 1/2... Discriminator Loss: 0.4562... Generator Loss: 1.5545
# Epoch 1/2... Discriminator Loss: 0.5210... Generator Loss: 1.3689
# Epoch 1/2... Discriminator Loss: 0.4342... Generator Loss: 1.6443
# Epoch 1/2... Discriminator Loss: 0.4059... Generator Loss: 2.1294
# Epoch 1/2... Discriminator Loss: 0.4634... Generator Loss: 1.6382
# Epoch 1/2... Discriminator Loss: 0.4586... Generator Loss: 1.5936
# Epoch 1/2... Discriminator Loss: 0.4380... Generator Loss: 1.6967
# Epoch 1/2... Discriminator Loss: 0.4262... Generator Loss: 1.6812
# Epoch 1/2... Discriminator Loss: 0.6336... Generator Loss: 1.4514
# Epoch 1/2... Discriminator Loss: 0.3988... Generator Loss: 1.6796
# Epoch 1/2... Discriminator Loss: 0.8944... Generator Loss: 0.7689
# Epoch 1/2... Discriminator Loss: 0.3371... Generator Loss: 1.8048
# Epoch 1/2... Discriminator Loss: 0.3860... Generator Loss: 1.7423
# Epoch 1/2... Discriminator Loss: 0.4166... Generator Loss: 1.5382
# Epoch 1/2... Discriminator Loss: 0.6089... Generator Loss: 2.0053
# Epoch 1/2... Discriminator Loss: 0.4801... Generator Loss: 2.2349
# Epoch 1/2... Discriminator Loss: 0.4127... Generator Loss: 2.1133
# Epoch 1/2... Discriminator Loss: 0.5573... Generator Loss: 2.1758
# Epoch 1/2... Discriminator Loss: 0.3499... Generator Loss: 1.7951
# Epoch 1/2... Discriminator Loss: 0.5145... Generator Loss: 1.2279
# Epoch 2/2... Discriminator Loss: 0.4134... Generator Loss: 1.8460
# Epoch 2/2... Discriminator Loss: 0.4710... Generator Loss: 1.5628
# Epoch 2/2... Discriminator Loss: 0.7946... Generator Loss: 0.8072
# Epoch 2/2... Discriminator Loss: 0.4681... Generator Loss: 1.3553
# Epoch 2/2... Discriminator Loss: 0.3311... Generator Loss: 1.8551
# Epoch 2/2... Discriminator Loss: 0.5067... Generator Loss: 1.2733
# Epoch 2/2... Discriminator Loss: 0.5854... Generator Loss: 1.1948
# Epoch 2/2... Discriminator Loss: 0.3297... Generator Loss: 1.9851
# Epoch 2/2... Discriminator Loss: 0.3888... Generator Loss: 1.4261
# Epoch 2/2... Discriminator Loss: 0.1990... Generator Loss: 2.4973
# Epoch 2/2... Discriminator Loss: 0.3603... Generator Loss: 1.8873
# Epoch 2/2... Discriminator Loss: 0.6144... Generator Loss: 1.0651
# Epoch 2/2... Discriminator Loss: 0.4935... Generator Loss: 1.9945
# Epoch 2/2... Discriminator Loss: 0.5370... Generator Loss: 1.2604
# Epoch 2/2... Discriminator Loss: 0.3182... Generator Loss: 2.0295
# Epoch 2/2... Discriminator Loss: 0.5005... Generator Loss: 1.2220
# Epoch 2/2... Discriminator Loss: 0.8655... Generator Loss: 1.5374
# Epoch 2/2... Discriminator Loss: 0.4971... Generator Loss: 1.2810
# Epoch 2/2... Discriminator Loss: 0.4388... Generator Loss: 1.6016
# Epoch 2/2... Discriminator Loss: 0.4952... Generator Loss: 1.4373
# Epoch 2/2... Discriminator Loss: 0.4268... Generator Loss: 1.4855
# Epoch 2/2... Discriminator Loss: 0.3421... Generator Loss: 1.9648
# Epoch 2/2... Discriminator Loss: 0.3612... Generator Loss: 1.9557
# Epoch 2/2... Discriminator Loss: 0.3583... Generator Loss: 2.0256
# Epoch 2/2... Discriminator Loss: 0.4323... Generator Loss: 1.8478
# Epoch 2/2... Discriminator Loss: 0.4741... Generator Loss: 1.3366
# Epoch 2/2... Discriminator Loss: 0.6674... Generator Loss: 1.2927
# Epoch 2/2... Discriminator Loss: 0.2696... Generator Loss: 2.4360
# Epoch 2/2... Discriminator Loss: 0.4163... Generator Loss: 1.5782
# Epoch 2/2... Discriminator Loss: 0.6122... Generator Loss: 0.8928
# Epoch 2/2... Discriminator Loss: 0.4065... Generator Loss: 1.8342
# Epoch 2/2... Discriminator Loss: 0.7743... Generator Loss: 0.9289
# Epoch 2/2... Discriminator Loss: 0.6666... Generator Loss: 1.2129
# Epoch 2/2... Discriminator Loss: 0.3864... Generator Loss: 1.8589
# Epoch 2/2... Discriminator Loss: 0.2978... Generator Loss: 1.9945
# Epoch 2/2... Discriminator Loss: 0.2050... Generator Loss: 2.5836
# Epoch 2/2... Discriminator Loss: 0.6365... Generator Loss: 2.2044
# Epoch 2/2... Discriminator Loss: 0.3614... Generator Loss: 1.7473

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 20
z_dim = 70
learning_rate = 0.0002
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Discriminator Loss: 0.3172... Generator Loss: 1.9397
# Epoch 1/1... Discriminator Loss: 0.5567... Generator Loss: 1.4268
# Epoch 1/1... Discriminator Loss: 0.4791... Generator Loss: 1.8436
# Epoch 1/1... Discriminator Loss: 0.6467... Generator Loss: 1.2168
# Epoch 1/1... Discriminator Loss: 0.6004... Generator Loss: 1.5726
# Epoch 1/1... Discriminator Loss: 0.8645... Generator Loss: 1.2482
# Epoch 1/1... Discriminator Loss: 0.8722... Generator Loss: 1.1118
# Epoch 1/1... Discriminator Loss: 0.9882... Generator Loss: 0.9677
# Epoch 1/1... Discriminator Loss: 0.9256... Generator Loss: 1.2226
# Epoch 1/1... Discriminator Loss: 1.1435... Generator Loss: 0.7116
# Epoch 1/1... Discriminator Loss: 0.8790... Generator Loss: 1.0642
# Epoch 1/1... Discriminator Loss: 0.9032... Generator Loss: 0.8756
# Epoch 1/1... Discriminator Loss: 0.5345... Generator Loss: 1.7252
# Epoch 1/1... Discriminator Loss: 0.8064... Generator Loss: 1.0747
# Epoch 1/1... Discriminator Loss: 0.7988... Generator Loss: 1.0583
# Epoch 1/1... Discriminator Loss: 0.9573... Generator Loss: 0.9115
# Epoch 1/1... Discriminator Loss: 0.9650... Generator Loss: 0.8004
# Epoch 1/1... Discriminator Loss: 0.9894... Generator Loss: 1.1615
# Epoch 1/1... Discriminator Loss: 0.9885... Generator Loss: 1.1420
# Epoch 1/1... Discriminator Loss: 1.1488... Generator Loss: 0.9094
# Epoch 1/1... Discriminator Loss: 1.2002... Generator Loss: 0.8404
# Epoch 1/1... Discriminator Loss: 1.2517... Generator Loss: 0.7166
# Epoch 1/1... Discriminator Loss: 1.2906... Generator Loss: 0.7666
# Epoch 1/1... Discriminator Loss: 0.9034... Generator Loss: 0.9466
# Epoch 1/1... Discriminator Loss: 1.1764... Generator Loss: 0.9334
# Epoch 1/1... Discriminator Loss: 1.0304... Generator Loss: 0.7570
# Epoch 1/1... Discriminator Loss: 1.1566... Generator Loss: 0.7434
# Epoch 1/1... Discriminator Loss: 1.2527... Generator Loss: 0.9852
# Epoch 1/1... Discriminator Loss: 0.6729... Generator Loss: 1.5493
# Epoch 1/1... Discriminator Loss: 1.1599... Generator Loss: 0.8171
# Epoch 1/1... Discriminator Loss: 0.8511... Generator Loss: 1.0207
# Epoch 1/1... Discriminator Loss: 0.9858... Generator Loss: 1.1069
# Epoch 1/1... Discriminator Loss: 1.1019... Generator Loss: 1.1289
# Epoch 1/1... Discriminator Loss: 1.2923... Generator Loss: 0.7010
# Epoch 1/1... Discriminator Loss: 1.1744... Generator Loss: 1.0142
# Epoch 1/1... Discriminator Loss: 1.3305... Generator Loss: 0.6571
# Epoch 1/1... Discriminator Loss: 1.2049... Generator Loss: 0.8259
# Epoch 1/1... Discriminator Loss: 1.1414... Generator Loss: 1.1941
# Epoch 1/1... Discriminator Loss: 1.1583... Generator Loss: 0.7239
# Epoch 1/1... Discriminator Loss: 0.9790... Generator Loss: 1.0491
# Epoch 1/1... Discriminator Loss: 1.4422... Generator Loss: 0.5726
# Epoch 1/1... Discriminator Loss: 1.2399... Generator Loss: 0.7315
# Epoch 1/1... Discriminator Loss: 1.0125... Generator Loss: 1.1578
# Epoch 1/1... Discriminator Loss: 1.0280... Generator Loss: 0.9621
# Epoch 1/1... Discriminator Loss: 1.2737... Generator Loss: 0.7401
# Epoch 1/1... Discriminator Loss: 1.3087... Generator Loss: 0.5968
# Epoch 1/1... Discriminator Loss: 1.1677... Generator Loss: 0.9330
# Epoch 1/1... Discriminator Loss: 1.0012... Generator Loss: 0.9457
# Epoch 1/1... Discriminator Loss: 1.0562... Generator Loss: 0.9445
# Epoch 1/1... Discriminator Loss: 1.0897... Generator Loss: 0.8652
# Epoch 1/1... Discriminator Loss: 1.0519... Generator Loss: 0.7844
# Epoch 1/1... Discriminator Loss: 0.9051... Generator Loss: 0.8566
# Epoch 1/1... Discriminator Loss: 0.9541... Generator Loss: 0.8855
# Epoch 1/1... Discriminator Loss: 0.9742... Generator Loss: 0.8726
# Epoch 1/1... Discriminator Loss: 1.2488... Generator Loss: 0.8924
# Epoch 1/1... Discriminator Loss: 1.2970... Generator Loss: 0.5931
# Epoch 1/1... Discriminator Loss: 0.9901... Generator Loss: 0.8622
# Epoch 1/1... Discriminator Loss: 1.1569... Generator Loss: 0.9134
# Epoch 1/1... Discriminator Loss: 0.9740... Generator Loss: 0.9699
# Epoch 1/1... Discriminator Loss: 1.1095... Generator Loss: 1.2440
# Epoch 1/1... Discriminator Loss: 1.2167... Generator Loss: 0.6671
# Epoch 1/1... Discriminator Loss: 0.9871... Generator Loss: 0.7680
# Epoch 1/1... Discriminator Loss: 1.0555... Generator Loss: 0.9385
# Epoch 1/1... Discriminator Loss: 0.8640... Generator Loss: 0.9198
# Epoch 1/1... Discriminator Loss: 1.3616... Generator Loss: 0.6435
# Epoch 1/1... Discriminator Loss: 1.0630... Generator Loss: 0.9003
# Epoch 1/1... Discriminator Loss: 0.8355... Generator Loss: 1.1956
# Epoch 1/1... Discriminator Loss: 0.3983... Generator Loss: 1.5570
# Epoch 1/1... Discriminator Loss: 0.8360... Generator Loss: 1.0629
# Epoch 1/1... Discriminator Loss: 0.8050... Generator Loss: 1.1205
# Epoch 1/1... Discriminator Loss: 0.7540... Generator Loss: 1.2463
# Epoch 1/1... Discriminator Loss: 0.9437... Generator Loss: 1.1050
# Epoch 1/1... Discriminator Loss: 1.0647... Generator Loss: 0.7194
# Epoch 1/1... Discriminator Loss: 1.3393... Generator Loss: 0.7212
# Epoch 1/1... Discriminator Loss: 1.0969... Generator Loss: 0.8970
# Epoch 1/1... Discriminator Loss: 0.6908... Generator Loss: 1.3382
# Epoch 1/1... Discriminator Loss: 0.8999... Generator Loss: 0.9358
# Epoch 1/1... Discriminator Loss: 0.9487... Generator Loss: 0.9492
# Epoch 1/1... Discriminator Loss: 0.6694... Generator Loss: 1.2217
# Epoch 1/1... Discriminator Loss: 0.8593... Generator Loss: 1.1924
# Epoch 1/1... Discriminator Loss: 0.9493... Generator Loss: 0.9683
# Epoch 1/1... Discriminator Loss: 1.0133... Generator Loss: 1.1312
# Epoch 1/1... Discriminator Loss: 1.0152... Generator Loss: 0.9446
# Epoch 1/1... Discriminator Loss: 0.8623... Generator Loss: 1.1299
# Epoch 1/1... Discriminator Loss: 0.9075... Generator Loss: 1.0874
# Epoch 1/1... Discriminator Loss: 0.9313... Generator Loss: 1.0908
# Epoch 1/1... Discriminator Loss: 0.9781... Generator Loss: 1.2408
# Epoch 1/1... Discriminator Loss: 1.0600... Generator Loss: 1.0542
# Epoch 1/1... Discriminator Loss: 1.3942... Generator Loss: 0.7143
# Epoch 1/1... Discriminator Loss: 1.1593... Generator Loss: 0.7282
# Epoch 1/1... Discriminator Loss: 1.0271... Generator Loss: 0.8172
# Epoch 1/1... Discriminator Loss: 1.1767... Generator Loss: 0.5266
# Epoch 1/1... Discriminator Loss: 1.0509... Generator Loss: 0.8852
# Epoch 1/1... Discriminator Loss: 1.0140... Generator Loss: 1.4142
# Epoch 1/1... Discriminator Loss: 1.0969... Generator Loss: 0.7080
# Epoch 1/1... Discriminator Loss: 1.2967... Generator Loss: 0.6666
# Epoch 1/1... Discriminator Loss: 1.2843... Generator Loss: 0.9145
# Epoch 1/1... Discriminator Loss: 0.9759... Generator Loss: 1.0180
# Epoch 1/1... Discriminator Loss: 1.0759... Generator Loss: 0.7451
# Epoch 1/1... Discriminator Loss: 1.1261... Generator Loss: 0.7479
# Epoch 1/1... Discriminator Loss: 1.0533... Generator Loss: 1.0838

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
